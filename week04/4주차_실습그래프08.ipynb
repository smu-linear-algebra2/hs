# %% [markdown]
# <a href="https://colab.research.google.com/github/smu-linear-algebra2/hs/blob/main/4%EC%A3%BC%EC%B0%A8_%EC%8B%A4%EC%8A%B5%EA%B7%B8%EB%9E%98%ED%94%8408.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

A = np.array([[0,1],[-2,1],[2,1]])
b = np.array([-1,-4,8])
x = np.linalg.lstsq(A,b,rcond=-1)[0]
x1, y1 = x
a1 = A[:,0]
a2 = A[:,1]
c1 = -b

fig = plt.figure()
ax = fig.add_subplot(1,1,1)

for c1,c2,c3 in zip(A[:,0],A[:,1],b):
  x = np.linspace(-20,20,100)
  y = (c3-c1*x)/c2
  plt.plot(x,y, color='black')

plt.plot(x1,y1,'ro')
ax.axis([-2,6,-2,6])
ax.set_xticks(range(-2,6))
ax.set_yticks(range(-2,6))
ax.grid()
ax.set_axisbelow(True)
ax.set_aspect('auto', adjustable='box')
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
plt.show()
